# %%
with open('/Users/pablom.perez/Desktop/6.780 - Inference and Information/Inference Project/project/data/alphabet.csv', 'r') as f:
    letters = f.read()
letters = letters.strip().split(',')
letter_to_int = {letters[i]: i for i in range(len(letters))}

y='hello'
y_indices = [letter_to_int[char] for char in y]
print(y_indices)
# Out:
# [7, 4, 11, 11, 14]

# %%
import numpy as np

P_char =
sumation = 0

for k in range (2,len(y))
    sumation += np.log(letter_transition_matrix[y_indices[k],y_indices[k-1]])

factor = np.log(letter_probabilities[y_indices[0]]) + sumation

# %%
import random
random.random()
# Out:
# 0.6713409253506273

# %%
y='hellofriend'
print(y[-2:])
# Out:
# nd

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
y[2:100]
# Out:
# 'llofriend'

# %%
import numpy as np
uniform = np.log2(28)
print(uniform)
# Out:
# 4.807354922057604

# %%
# !pwd
# Out:
# /Users/pablom.perez/Desktop/6.780 - Inference and Information/Inference Project/project/src

# %%
letter_probs = np.loadtxt('../data/letter_probabilities.csv', delimiter=',')

letter_probs.shape
# Out:
# (28,)
